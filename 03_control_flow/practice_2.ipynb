# %% [markdown]
# # 1.Take a number and check whether it is negative, positive, or zero.

# %%
n = int(input("Enter a number"))

if n>0:
    print("Postive number")
elif n<0:
    print("Negative number")
else:
    print("zero")
# Out:
# Enter a number 0
# zero

# %% [markdown]
# # 2. Take two numbers and check whether both are even.

# %%
a = 6
b = 4
if a%2==0 and b%2==0:
    print("Both are even")
else:
    print("both are not even")
# Out:
# Both are even

# %% [markdown]
# # 3. Take a number and check whether it is divisible by 5 but not by 10.

# %%
a = 35
if a%5==0 and a%10!=0:
    print("divisble by 5 but not by 10")
else:
    print("Nor divisble by 5 nor by 10")
# Out:
# divisble by 5 but not by 10

# %% [markdown]
# # 4. Take a character and check whether it is a vowel or consonant.

# %%
ch = input("Enter a character")
if ch=="a" or ch=="e" or ch=="i"or ch=="o" or ch=="u":
    print("the character is vowel")
else:
    print("the character is consonant")
# Out:
# Enter a character t
# the character is consonant

# %% [markdown]
# # 5. Take a number and check whether it is a two-digit number.

# %%
a = int(input("Enter a number"))
if a<100:
    print("two-digit number")
else:
    print("not a 2 digit number")
# Out:
# Enter a number 23
# two-digit number

# %% [markdown]
# # 6.Take three numbers and check whether any two are equal.

# %%
a = 78
b = 90
c = 78
if a==b or b==c or a==c :
    print("2 numbers are equal")
else:
    print("No 2 numebrs are equal")
# Out:
# 2 numbers are equal

# %% [markdown]
# # 7. Take the age of a person and check whether the person is a child, teenager, or adult.

# %%
age = 13
if age<12:
    print("child")
elif age>12 and age<18:
    print("Teenager")
else:
    print("adult")
# Out:
# Teenager

# %% [markdown]
# # 8. Take a number and check whether it is divisible by 4 but not by 6.

# %%
num = 24

if num%4==0 and num%6!=0:
    print("divisible by 4 but not by 6")
else:
    print("condition not satisfied")
# Out:
# condition not satisfied

# %% [markdown]
# # 9.Take two numbers and check whether their sum is greater than 100.

# %%
a = 56
b = 45
if a+b>100:
    print("the sum is greater then 100")
else:
    print("the sum is not greater then 100")
# Out:
# the sum is greater then 100

# %% [markdown]
# # 10. Take a year and check whether it is a century year or not.

# %%
year = int(input("Enter a year"))

if year % 100 == 0:
    print("Century Year")
else:
    print("Not a Century Year")
# Out:
# Enter a year 1200
# Century Year

# %% [markdown]
# # 11. Take marks of a student and check whether the student is pass or fail (pass ≥ 33).

# %%
marks = int(input("Enter the marks of the student"))

if marks >= 33:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter the marks of the student 45
# Pass

# %% [markdown]
# # 12. Take three angles and check whether they form a valid triangle.

# %%
a = 45
b = 45
c = 90

if a+b+c == 180 and a>0 and b>0 and c>0:
    print("Valid triangle")
else:
    print("Not a valid triangle")
# Out:
# Valid triangle

# %% [markdown]
# # 13. Take a character and check whether it is an uppercase or lowercase alphabet.

# %%
ch = "D"

if ch>="A" and ch<="Z":
    print("uppercase")
elif ch>="a" and ch<="z":
    print("lowercase")
else:
     print("Not an Alphabet")
# Out:
# uppercase

# %% [markdown]
# # 14. Take a number and check whether it is multiple of 9 but not of 3

# %%
n = int(input("Enter a number: "))

if n % 9 == 0 and n % 3 != 0:
    print("Condition satisfied")
else:
    print("Condition not possible")
# Out:
# Enter a number:  45
# Condition not possible

# %% [markdown]
# # 15. Take two numbers and check whether first is divisible by second.

# %%
a=10
b=5

if a%b==0:
    print("the first number is divisble by second")
else:
    print("not divisble")

# %% [markdown]
# # 16. Take a number and check whether it lies outside the range 10–50.

# %%
n = 51

if n < 10 or n > 50:
    print("Outside the range")
else:
    print("Inside the range")
# Out:
# Outside the range

# %% [markdown]
# # 17. Take the cost price and selling price and check whether there is profit, loss, or no profit no loss.

# %%
a = int(input("enter the cost price"))
b = int(input("enter the selling price"))

if a>b:
    print("Loss")
elif a<b:
    print("profit")
else:
    print("no profit no loss")
# Out:
# enter the cost price 100
# enter the selling price 100
# no profit no loss

# %% [markdown]
# # 18. Take a number and check whether it is a perfect square (no loops).

# %%
n = int(input("Enter a number: "))

root = int(n ** 0.5)

if root * root == n:
    print("Perfect square")
else:
    print("Not a perfect square")
# Out:
# Enter a number:  36
# Perfect square

# %% [markdown]
# # 19. Take three numbers and check whether they are in increasing order.

# %%
a = 23
b = 34
c = 56

if a<b<c:
    print("increasing order")
else:
    print("not in increasing order")
# Out:
# increasing order

# %% [markdown]
# # 20. Take a character and check whether it is a valid hexadecimal digit
#   hexadecimal diigits lies between (0–9 or A–F).

# %%
ch = input("enter a charcter")

if ('0'<= ch <='9') or ('A'<= ch <= 'Z') or ('a'<= ch <='z'):
    print("Hexadecimal digit")
else:
    print("not a hexadecimal digit")
# Out:
# enter a charcter 5f
# Hexadecimal digit
