# %% [markdown]
# # If else statements
#
# In Python, conditional statements (if , elif , and else ) are used to control the flow of a program based on conditions. These are essential in data science for handling different scenarios in data processing, decision-making, and logic execution

# %% [markdown]
# # Basic if Statement
#
# The if statement allows you to execute a block of code only if a condition is
# True

# %%
x = 10
if x>5:
 print("x is greater then 5")
# Out:
# x is greater then 5

# %% [markdown]
# # Explanation:
# - The condition x > 5 is checked.
# - if True the indented block under if runs.
# - if False nothing happens.

# %% [markdown]
# # if-else Statement
#
# The else block executes when the if condition is False.

# %%
age = 18
if age>=18:
    print("Elig. for voting")
else:
    print("Not Elig. for voting")
# Out:
# Elig. for voting

# %% [markdown]
# # Explanation:
# - if X >=18 ,it prints elig, for voting
# - otherwise, the else block will executes.

# %% [markdown]
#  # if-elif-else Statement
#
# When multiple conditions need to be checked sequentially, use  elif (short for "else if”).

# %%
marks = int(input("Enter your marks :- "))
if marks >80:
    print("A")
elif marks >70:
    print("B")
elif marks >60 :
    print("C")
elif marks >50:
    print("D")
else:
    print("fail")
# Out:
# Enter your marks :-  56
# D

# %% [markdown]
# # Explanation:
# - The conditions are checked from top to bottom.
# - The first True condition executes, and the rest are skipped.

# %% [markdown]
# # Using if-elif-else in in Data Science
#
# Conditional statements are widely used in data science for filtering, cleaning, and
# decision-making

# %% [markdown]
# # Example: Categorizing Data

# %%
age = 89
if age < 18:
    category = "Minor"
elif age < 65:
    category = "Adult"
else:
    category = "Senior Citizen"
print("Category:", category)
# Out:
# Category: Senior Citizen

# %% [markdown]
# # Summary
# - if : Executes if the condition is True .
# - if-else : Adds an alternative block if the condition is False.
# - if-elif-else : Handles multiple conditions.
# - Useful in data science for logic-based decision-making
