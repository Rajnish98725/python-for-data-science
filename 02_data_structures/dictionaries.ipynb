# %% [markdown]
# # DICTIONARY

# %%
# dic is a key value pair

# %%
info ={
    "name":"Rajnish",
    "add": "Bihar",
    "class":"B.tech",
    "rollno.": 12201056
}

# %%
info
# Out:
# {'name': 'Rajnish', 'add': 'Bihar', 'class': 'B.tech', 'rollno.': 12201056}

# %% [markdown]
# # Methods

# %%
info.keys()
# Out:
# dict_keys(['name', 'add', 'class', 'rollno.'])

# %%
info.values()
# Out:
# dict_values(['Rajnish', 'Bihar', 'B.tech', 12201056])

# %%
info.items()
# Out:
# dict_items([('name', 'Rajnish'), ('add', 'Bihar'), ('class', 'B.tech'), ('rollno.', 12201056)])

# %%
info.get("name")
# Out:
# 'Rajnish'

# %%
info["name"]
# Out:
# 'Rajnish'

# %%
student = {
"name": "Alice",
"age": 25,
"grade": "A"
}

info.update(student)
info
# Out:
# {'name': 'Alice',
#  'add': 'Bihar',
#  'class': 'B.tech',
#  'rollno.': 12201056,
#  'age': 25,
#  'grade': 'A'}

# %%
info.update({"name":"Rajnish"})
info
# Out:
# {'name': 'Rajnish',
#  'add': 'Bihar',
#  'class': 'B.tech',
#  'rollno.': 12201056,
#  'age': 25,
#  'grade': 'A'}

# %%
info.pop("grade")
# Out:
# 'A'

# %%
info
# Out:
# {'name': 'Rajnish',
#  'add': 'Bihar',
#  'class': 'B.tech',
#  'rollno.': 12201056,
#  'age': 25}

# %%
info.popitem()
# Out:
# ('age', 25)

# %%
info
# Out:
# {'name': 'Rajnish', 'add': 'Bihar', 'class': 'B.tech', 'rollno.': 12201056}

# %%
# info.setdefault("city","gopalganj")
info.update({"city":"gopalganj"})

# %%
info
# Out:
# {'name': 'Rajnish',
#  'add': 'Bihar',
#  'class': 'B.tech',
#  'rollno.': 12201056,
#  'city': 'gopalganj'}

# %%
info_copy=info.copy()
info_copy
# Out:
# {'name': 'Rajnish',
#  'add': 'Bihar',
#  'class': 'B.tech',
#  'rollno.': 12201056,
#  'city': 'gopalganj'}

# %%
print(info_copy)
# Out:
# {'name': 'Rajnish', 'add': 'Bihar', 'class': 'B.tech', 'rollno.': 12201056, 'city': 'gopalganj'}

# %%
values=list(info.values())
values
# Out:
# ['Rajnish', 'Bihar', 'B.tech', 12201056, 'gopalganj']

# %%
keys = list(info.keys())
keys
# Out:
# ['name', 'add', 'class', 'rollno.', 'city']

# %%
items= list(info.items())
items
# Out:
# [('name', 'Rajnish'),
#  ('add', 'Bihar'),
#  ('class', 'B.tech'),
#  ('rollno.', 12201056),
#  ('city', 'gopalganj')]

# %%
parents ={
    "child1":{
        "name":"sham",
        "age":21,
        "class":"Btech"
    },
    "child2":{
         "name":"sham",
        "age":21,
        "class":"Btech"
      },
    "child3":
            {
     "name":"sham",
        "age":21,
        "class":"Btech"
              }
}

# %%
parents
# Out:
# {'child1': {'name': 'sham', 'age': 21, 'class': 'Btech'},
#  'child2': {'name': 'sham', 'age': 21, 'class': 'Btech'},
#  'child3': {'name': 'sham', 'age': 21, 'class': 'Btech'}}

# %%
name = parents["child1"]["name"]
print(name)
# Out:
# sham

# %%
keys_child = parents["child2"].keys()

keys_parents= parents.keys()
print(keys_child)
print(keys_parents)
# Out:
# dict_keys(['name', 'age', 'class'])
# dict_keys(['child1', 'child2', 'child3'])

# %%
namec2= parents["child2"]["name"]
namec2
classc3= parents["child3"]["class"]
classc3
agec1= parents["child1"]["age"]
agec1
# Out:
# 21
